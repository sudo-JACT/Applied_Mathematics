# %%
from AppliedMathematics.quadrature.Guass import Gauss_Legendre
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from AppliedMathematics.quadrature.Guass import Gauss_Legendre
#
# ModuleNotFoundError: No module named 'AppliedMathematics.quadrature.Guass'

# %%
print("test2")
# Out:
# test2

# %% [markdown]
# test
# $f(x)=x^2$

# %%
from Gauss import *

x = Symbol("x")
    
f = 1
    
n = 2
    
print(Gauss_Legendre(n, f, x))
print(Gauss_Chebyshev_1(n, f, x))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from Gauss import *
#       3 x = Symbol("x")
#       5 f = 1
#
# ModuleNotFoundError: No module named 'Gauss'
