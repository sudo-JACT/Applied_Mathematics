# %%
from AppliedMathematics import *

# %%
print("test2")
# Out:
# test2

# %% [markdown]
# test
# $f(x)=x^2$

# %%
x = Symbol("x")

a, b = 0, 1 

f = x
    
n = 2

e = 10**(-3)

y = 3
    
xn = [0.0, 1, 2, 4, 5]
yn = [0.0, 1, 2, 4, 5]
    
print(Linear_Spline(y, xn, yn))

print(f"Iterated Cavalieri-Simpson of f(x)={f}: {Iterated_Cavalieri_Simpson(a, b, e, n, f, x)[1]}")
print(version())
print(Gauss_Legendre(n, f, x, a, b))
print(Gauss_Chebyshev_1(n, f, x))
# Out:
# 3.0
# Iterated Cavalieri-Simpson of f(x)=x: 0.5
# 1.0.0
# 0.5
# 1.743934249004316e-16

# %% [markdown]
# ```python
#
# def test():
#
#     pass
#
# ```
