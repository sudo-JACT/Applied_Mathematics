# %%
from AppliedMathematics import *

# %%
print("test2")
# Out:
# test2

# %% [markdown]
# test
# $f(x)=x^2$

# %%
x = Symbol("x")

a, b = 0, 1 

f = x
    
n = 2

e = 10**(-3)

y = 3
    
xn = [0.0, 1, 2, 4, 5]
yn = [0.0, 1, 2, 4, 5]
    
print(Linear_Spline(y, xn, yn))


print(f"Iterated Cavalieri-Simpson of f(x)={f}: {Cavalieri_Simpson_Comp(a, b, e, n, f, x)[1]}")
print(version())
print(Gauss_Legendre(n, f, x, a, b))
print(Gauss_Chebyshev_1(n, f, x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 16
#      13 xn = [0.0, 1, 2, 4, 5]
#      14 yn = [0.0, 1, 2, 4, 5]
# ---> 16 print(Linear_Spline(y, xn, yn))
#      19 print(f"Iterated Cavalieri-Simpson of f(x)={f}: {Cavalieri_Simpson_Comp(a, b, e, n, f, x)[1]}")
#      20 print(version())
#
# NameError: name 'Linear_Spline' is not defined
