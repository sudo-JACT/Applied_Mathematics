# %%
print("test")
# Out:
# test

# %%
print("test2")
# Out:
# test2

# %% [markdown]
# test
# $f(x)=x^2$

# %%
from Gauss import *

x = Symbol("x")
    
f = 1
    
n = 2
    
print(Gauss_Legendre(n, f, x))
print(Gauss_Chebyshev_1(n, f, x))
# Out:
# 2.0
# 3.141592653589793
